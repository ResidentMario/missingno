# %%
import missingno.missingno as msno

# %%
# %matplotlib inline

# %%
import pandas as pd
collisions = pd.read_csv("NYPD_Motor_Vehicle_Collisions.csv")

# %%
# %load_ext autoreload
# %autoreload 2

# %%
msno.matrix(collisions.sample(100))

# %%
msno.geoplot(collisions.sample(1000), x='LATITUDE', y='LONGITUDE', histogram=True)
