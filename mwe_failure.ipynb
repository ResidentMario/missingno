# %%
from shapely.geometry import Polygon

example_coordinates_1 = [(-73.9706078, 40.5765074),
 (-73.985654, 40.5806604),
 (-74.0331615, 40.6134019),
 (-74.03607109999999, 40.6255989),
 (-74.03678570000001, 40.6343518),
 (-73.9877415, 40.7006626),
 (-73.9524386, 40.734688500000004),
 (-73.8701281, 40.6907089),
 (-73.8712013, 40.6802223),
 (-73.8757932, 40.6693333),
 (-73.9078755, 40.596511299999996),
 (-73.9388668, 40.5783751),
 (-73.9509957, 40.5770881),
 (-73.9706078, 40.5765074)]
example_coordinates_2 = [(-73.86162259999999, 40.570370000000004),
 (-73.9522573, 40.740916299999995),
 (-73.9550425, 40.7473319),
 (-73.9405343, 40.7634232),
 (-73.9096436, 40.7720903),
 (-73.8166268, 40.790257000000004),
 (-73.7148158, 40.757316100000004),
 (-73.7395512, 40.6652573),
 (-73.7987136, 40.5982411),
 (-73.86162259999999, 40.570370000000004)]
example_polygon_1 = Polygon(example_coordinates_1)
example_polygon_2 = Polygon(example_coordinates_2)

# %%
example_polygon_1

# %%
example_polygon_2

# %%
import descartes
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(24, 10))
ax = plt.subplot(111)
# fig, ax = plt.subplots()

for poly in [example_polygon_1, example_polygon_2]:
    ax.add_patch(descartes.PolygonPatch(poly, fc='red'))

plt.show()
